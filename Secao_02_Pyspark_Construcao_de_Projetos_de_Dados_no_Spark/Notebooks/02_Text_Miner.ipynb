# %%
# Carregando os dados sobre economia
data = spark.sparkContext.textFile("/FileStore/regiao_*.txt")

# %%
# Separação das palavras com o uso da função lambda e split
palavras = data.flatMap(lambda x: x.split(" "))

# %%
# Exibição da coleção de palavras
for plv in palavras.collect():
  print(plv)

# %%
# Função que transforma em minuscula todas as palavras
def func1(x):
  minuscula = x.lower()
  return minuscula


allpalminuscula = palavras.map(lambda x: func1(x))

# %%
# Exibe a coleção de dados
allpalminuscula.collect()
# Out:
# Out[34]: ['no',
#  'norte',
#  'do',
#  'país,',
#  'região',
#  'povoada',
#  'recentemente,',
#  'foram',
#  'criados',
#  'alguns',
#  'órgãos',
#  'governamentais',
#  'responsáveis',
#  'pelo',
#  'seu',
#  'estímulo',
#  'econômico',
#  'na',
#  'década',
#  'de',
#  '1960.',
#  'dentre',
#  'eles',
#  'podemos',
#  'destacar',
#  'a',
#  'superintendência',
#  'do',
#  'desenvolvimento',
#  'da',
#  'amazônia',
#  '(sudam)',
#  'e',
#  'a',
#  'superintendência',
#  'da',
#  'zona',
#  'franca',
#  'de',
#  'manaus',
#  '(suframa).',
#  '',
#  'esta',
#  'última',
#  'corresponde',
#  'a',
#  'um',
#  'grande',
#  'polo',
#  'industrial,',
#  'idealizado',
#  'em',
#  '1967',
#  'e',
#  'localizado',
#  'em',
#  'manaus,',
#  'que',
#  'abriga',
#  'grandes',
#  'multinacionais,',
#  'propiciando',
#  'um',
#  'enorme',
#  'desenvolvimento',
#  'industrial',
#  'e',
#  'geração',
#  'de',
#  'empregos',
#  'para',
#  'a',
#  'região.',
#  '',
#  'esse',
#  'polo',
#  'concentra',
#  'três',
#  'tipos',
#  'de',
#  'atividades:',
#  'comercial,',
#  'agropecuária',
#  'e',
#  'industrial',
#  '(a',
#  'mais',
#  'forte',
#  'de',
#  'todas).',
#  'de',
#  'acordo',
#  'com',
#  'a',
#  'suframa,',
#  'existem',
#  'mais',
#  'de',
#  '600',
#  'indústrias',
#  'no',
#  'polo',
#  'e',
#  'uma',
#  'geração',
#  'de',
#  'mais',
#  'de',
#  '500',
#  'mil',
#  'empregos,',
#  'diretos',
#  'e',
#  'indiretos.',
#  'as',
#  'áreas',
#  'de',
#  'produção',
#  'industrial',
#  'que',
#  'se',
#  'destacam',
#  'são:',
#  'eletroeletrônicos',
#  '(celulares,',
#  'tvs),',
#  'duas',
#  'rodas',
#  '(motocicletas)',
#  'e',
#  'química',
#  '(produção',
#  'de',
#  'matéria-prima',
#  'para',
#  'refrigerante).',
#  'no',
#  'sul',
#  'do',
#  'país,',
#  'há',
#  'destaques',
#  'em',
#  'vários',
#  'setores',
#  'econômicos',
#  'brasileiros.',
#  'por',
#  'ser',
#  'uma',
#  'região',
#  'bem',
#  'desenvolvida',
#  'no',
#  'aspecto',
#  'tecnológico',
#  'e',
#  'industrial,',
#  'são',
#  'muito',
#  'comuns',
#  'áreas',
#  'em',
#  'que',
#  'esses',
#  'dois',
#  'aspectos',
#  'unem-se,',
#  'como',
#  'na',
#  'criação',
#  'de',
#  'animais',
#  'em',
#  'larga',
#  'escala.',
#  '',
#  'a',
#  'região',
#  'sul',
#  'é',
#  'líder',
#  'na',
#  'criação',
#  'de',
#  'suínos',
#  'e',
#  'aves',
#  'no',
#  'brasil,',
#  'tendo',
#  'os',
#  'maiores',
#  'rebanhos',
#  'nas',
#  'duas',
#  'categorias,',
#  'de',
#  'acordo',
#  'com',
#  'o',
#  'sistema',
#  'ibge',
#  'de',
#  'recuperação',
#  'automática',
#  '(sidra).',
#  '',
#  'as',
#  'condições',
#  'climáticas',
#  'da',
#  'região',
#  'assim',
#  'como',
#  'o',
#  'solo',
#  'fértil',
#  'favorecem',
#  'a',
#  'agricultura,',
#  'com',
#  'destaque',
#  'para',
#  'a',
#  'produção',
#  'de',
#  'milho',
#  'no',
#  'paraná,',
#  'de',
#  'maçãs',
#  'no',
#  'rio',
#  'grande',
#  'do',
#  'sul',
#  'e',
#  'em',
#  'santa',
#  'catarina,',
#  'além',
#  'do',
#  'cultivo',
#  'da',
#  'uva,',
#  'que',
#  'é',
#  'marcante',
#  'no',
#  'nordeste',
#  'rio-grandense.',
#  '',
#  'já',
#  'as',
#  'atividades',
#  'industriais',
#  'estão',
#  'relacionadas',
#  'à',
#  'produção',
#  'de',
#  'matéria-prima,',
#  'como',
#  'têxteis,',
#  'lacticínios,',
#  'frigoríficos,',
#  'grãos',
#  'etc.',
#  'o',
#  'estado',
#  'mais',
#  'industrializado',
#  'é',
#  'o',
#  'rio',
#  'grande',
#  'do',
#  'sul,',
#  'com',
#  'grandes',
#  'complexos',
#  'industriais',
#  'na',
#  'região',
#  'metropolitana',
#  'de',
#  'porto',
#  'alegre.']

# %%
# Cria a lista de stop words que será filtrada
stop_words = ["e", "do", "das", "na", "há", "ser", "são", "para", "por", "as", "em", "no", "nas", "uma", "que", "como", "com", "", "os", "o", "a", "da", "de", "nas", "é", "á", "já"]

filtro_palavras = allpalminuscula.filter(lambda x: x not in stop_words)

# %%
# Exibe a coleção de dados já filtrada
filtro_palavras.collect()
# Out:
# Out[38]: ['norte',
#  'país,',
#  'região',
#  'povoada',
#  'recentemente,',
#  'foram',
#  'criados',
#  'alguns',
#  'órgãos',
#  'governamentais',
#  'responsáveis',
#  'pelo',
#  'seu',
#  'estímulo',
#  'econômico',
#  'década',
#  '1960.',
#  'dentre',
#  'eles',
#  'podemos',
#  'destacar',
#  'superintendência',
#  'desenvolvimento',
#  'amazônia',
#  '(sudam)',
#  'superintendência',
#  'zona',
#  'franca',
#  'manaus',
#  '(suframa).',
#  'esta',
#  'última',
#  'corresponde',
#  'um',
#  'grande',
#  'polo',
#  'industrial,',
#  'idealizado',
#  '1967',
#  'localizado',
#  'manaus,',
#  'abriga',
#  'grandes',
#  'multinacionais,',
#  'propiciando',
#  'um',
#  'enorme',
#  'desenvolvimento',
#  'industrial',
#  'geração',
#  'empregos',
#  'região.',
#  'esse',
#  'polo',
#  'concentra',
#  'três',
#  'tipos',
#  'atividades:',
#  'comercial,',
#  'agropecuária',
#  'industrial',
#  '(a',
#  'mais',
#  'forte',
#  'todas).',
#  'acordo',
#  'suframa,',
#  'existem',
#  'mais',
#  '600',
#  'indústrias',
#  'polo',
#  'geração',
#  'mais',
#  '500',
#  'mil',
#  'empregos,',
#  'diretos',
#  'indiretos.',
#  'áreas',
#  'produção',
#  'industrial',
#  'se',
#  'destacam',
#  'são:',
#  'eletroeletrônicos',
#  '(celulares,',
#  'tvs),',
#  'duas',
#  'rodas',
#  '(motocicletas)',
#  'química',
#  '(produção',
#  'matéria-prima',
#  'refrigerante).',
#  'sul',
#  'país,',
#  'destaques',
#  'vários',
#  'setores',
#  'econômicos',
#  'brasileiros.',
#  'região',
#  'bem',
#  'desenvolvida',
#  'aspecto',
#  'tecnológico',
#  'industrial,',
#  'muito',
#  'comuns',
#  'áreas',
#  'esses',
#  'dois',
#  'aspectos',
#  'unem-se,',
#  'criação',
#  'animais',
#  'larga',
#  'escala.',
#  'região',
#  'sul',
#  'líder',
#  'criação',
#  'suínos',
#  'aves',
#  'brasil,',
#  'tendo',
#  'maiores',
#  'rebanhos',
#  'duas',
#  'categorias,',
#  'acordo',
#  'sistema',
#  'ibge',
#  'recuperação',
#  'automática',
#  '(sidra).',
#  'condições',
#  'climáticas',
#  'região',
#  'assim',
#  'solo',
#  'fértil',
#  'favorecem',
#  'agricultura,',
#  'destaque',
#  'produção',
#  'milho',
#  'paraná,',
#  'maçãs',
#  'rio',
#  'grande',
#  'sul',
#  'santa',
#  'catarina,',
#  'além',
#  'cultivo',
#  'uva,',
#  'marcante',
#  'nordeste',
#  'rio-grandense.',
#  'já',
#  'atividades',
#  'industriais',
#  'estão',
#  'relacionadas',
#  'à',
#  'produção',
#  'matéria-prima,',
#  'têxteis,',
#  'lacticínios,',
#  'frigoríficos,',
#  'grãos',
#  'etc.',
#  'estado',
#  'mais',
#  'industrializado',
#  'rio',
#  'grande',
#  'sul,',
#  'grandes',
#  'complexos',
#  'industriais',
#  'região',
#  'metropolitana',
#  'porto',
#  'alegre.']

# %%
# Preparando o contador para somar a quantidade de palavras, colocando o número 1 ao lado das palavras
freqpal = filtro_palavras.map(lambda x: [x, 1])

# %%
# Frequência de palavras
freqpal.collect()
# Out:
# Out[40]: [['norte', 1],
#  ['país,', 1],
#  ['região', 1],
#  ['povoada', 1],
#  ['recentemente,', 1],
#  ['foram', 1],
#  ['criados', 1],
#  ['alguns', 1],
#  ['órgãos', 1],
#  ['governamentais', 1],
#  ['responsáveis', 1],
#  ['pelo', 1],
#  ['seu', 1],
#  ['estímulo', 1],
#  ['econômico', 1],
#  ['década', 1],
#  ['1960.', 1],
#  ['dentre', 1],
#  ['eles', 1],
#  ['podemos', 1],
#  ['destacar', 1],
#  ['superintendência', 1],
#  ['desenvolvimento', 1],
#  ['amazônia', 1],
#  ['(sudam)', 1],
#  ['superintendência', 1],
#  ['zona', 1],
#  ['franca', 1],
#  ['manaus', 1],
#  ['(suframa).', 1],
#  ['esta', 1],
#  ['última', 1],
#  ['corresponde', 1],
#  ['um', 1],
#  ['grande', 1],
#  ['polo', 1],
#  ['industrial,', 1],
#  ['idealizado', 1],
#  ['1967', 1],
#  ['localizado', 1],
#  ['manaus,', 1],
#  ['abriga', 1],
#  ['grandes', 1],
#  ['multinacionais,', 1],
#  ['propiciando', 1],
#  ['um', 1],
#  ['enorme', 1],
#  ['desenvolvimento', 1],
#  ['industrial', 1],
#  ['geração', 1],
#  ['empregos', 1],
#  ['região.', 1],
#  ['esse', 1],
#  ['polo', 1],
#  ['concentra', 1],
#  ['três', 1],
#  ['tipos', 1],
#  ['atividades:', 1],
#  ['comercial,', 1],
#  ['agropecuária', 1],
#  ['industrial', 1],
#  ['(a', 1],
#  ['mais', 1],
#  ['forte', 1],
#  ['todas).', 1],
#  ['acordo', 1],
#  ['suframa,', 1],
#  ['existem', 1],
#  ['mais', 1],
#  ['600', 1],
#  ['indústrias', 1],
#  ['polo', 1],
#  ['geração', 1],
#  ['mais', 1],
#  ['500', 1],
#  ['mil', 1],
#  ['empregos,', 1],
#  ['diretos', 1],
#  ['indiretos.', 1],
#  ['áreas', 1],
#  ['produção', 1],
#  ['industrial', 1],
#  ['se', 1],
#  ['destacam', 1],
#  ['são:', 1],
#  ['eletroeletrônicos', 1],
#  ['(celulares,', 1],
#  ['tvs),', 1],
#  ['duas', 1],
#  ['rodas', 1],
#  ['(motocicletas)', 1],
#  ['química', 1],
#  ['(produção', 1],
#  ['matéria-prima', 1],
#  ['refrigerante).', 1],
#  ['sul', 1],
#  ['país,', 1],
#  ['destaques', 1],
#  ['vários', 1],
#  ['setores', 1],
#  ['econômicos', 1],
#  ['brasileiros.', 1],
#  ['região', 1],
#  ['bem', 1],
#  ['desenvolvida', 1],
#  ['aspecto', 1],
#  ['tecnológico', 1],
#  ['industrial,', 1],
#  ['muito', 1],
#  ['comuns', 1],
#  ['áreas', 1],
#  ['esses', 1],
#  ['dois', 1],
#  ['aspectos', 1],
#  ['unem-se,', 1],
#  ['criação', 1],
#  ['animais', 1],
#  ['larga', 1],
#  ['escala.', 1],
#  ['região', 1],
#  ['sul', 1],
#  ['líder', 1],
#  ['criação', 1],
#  ['suínos', 1],
#  ['aves', 1],
#  ['brasil,', 1],
#  ['tendo', 1],
#  ['maiores', 1],
#  ['rebanhos', 1],
#  ['duas', 1],
#  ['categorias,', 1],
#  ['acordo', 1],
#  ['sistema', 1],
#  ['ibge', 1],
#  ['recuperação', 1],
#  ['automática', 1],
#  ['(sidra).', 1],
#  ['condições', 1],
#  ['climáticas', 1],
#  ['região', 1],
#  ['assim', 1],
#  ['solo', 1],
#  ['fértil', 1],
#  ['favorecem', 1],
#  ['agricultura,', 1],
#  ['destaque', 1],
#  ['produção', 1],
#  ['milho', 1],
#  ['paraná,', 1],
#  ['maçãs', 1],
#  ['rio', 1],
#  ['grande', 1],
#  ['sul', 1],
#  ['santa', 1],
#  ['catarina,', 1],
#  ['além', 1],
#  ['cultivo', 1],
#  ['uva,', 1],
#  ['marcante', 1],
#  ['nordeste', 1],
#  ['rio-grandense.', 1],
#  ['já', 1],
#  ['atividades', 1],
#  ['industriais', 1],
#  ['estão', 1],
#  ['relacionadas', 1],
#  ['à', 1],
#  ['produção', 1],
#  ['matéria-prima,', 1],
#  ['têxteis,', 1],
#  ['lacticínios,', 1],
#  ['frigoríficos,', 1],
#  ['grãos', 1],
#  ['etc.', 1],
#  ['estado', 1],
#  ['mais', 1],
#  ['industrializado', 1],
#  ['rio', 1],
#  ['grande', 1],
#  ['sul,', 1],
#  ['grandes', 1],
#  ['complexos', 1],
#  ['industriais', 1],
#  ['região', 1],
#  ['metropolitana', 1],
#  ['porto', 1],
#  ['alegre.', 1]]

# %%
# Utilizando a função ReduceKey para somar o contador
from operator import add

totalpal = freqpal.reduceByKey(add)

# %%
# Exibindo a contagem ao lado da palavra
totalpal.collect()

# %%
# Realizando um for interativo para colocar as palavras em ordem descendente
for i in totalpal.sortBy(lambda x: x[1], ascending=False).collect():
  print(i)
